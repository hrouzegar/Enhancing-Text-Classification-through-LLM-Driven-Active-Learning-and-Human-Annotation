# %%
avg_lentgh= 230.15 #imdb
few_lentgh= 762 #imdb
manual_price= (91.95/50000) * avg_lentgh
llm_price = (0.0015 / 750) * avg_lentgh
few_price = (0.0015 / 750) * (avg_lentgh+few_lentgh)

# %%
print(manual_price)
print(llm_price)
# Out:
# 0.42324585000000003
# 0.00046029999999999997

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths
accuracy_file_paths = [

]
count_file_paths = [

]

accuracy_series = []
count_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for count in count_file_paths:
    df = pd.read_excel(count)
    count_series.append(df[0])

# Calculate expenses for each scenario
pool_tot_expenses = [(200 + i * 20) * llm_price for i in range(len(accuracy_series[0]))]
pool_tot100_expenses = [(200 + i * 20) * manual_price for i in range(len(accuracy_series[0]))]
pool_tot70_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[0])
]
pool_tot80_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[1])
]
pool_tot90_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[2])
]
pool_tot_few_expenses= [
    (count * few_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[3])
]
# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(pool_tot_expenses, accuracy_series[0], label='GPT only')
plt.plot(pool_tot70_expenses, accuracy_series[1], label='GPT confidence > 70')
plt.plot(pool_tot80_expenses, accuracy_series[2], label='GPT confidence > 80')
plt.plot(pool_tot90_expenses, accuracy_series[3], label='GPT confidence > 90')
plt.plot(pool_tot100_expenses, accuracy_series[4], label='Human only')
plt.plot(pool_tot_few_expenses, accuracy_series[5], label='Few-shot (<70)')

plt.ylabel('Expenses')
plt.xlabel('F1-Score')
plt.title('Cost per F1-Score IMDB')
plt.legend()
plt.grid()

plt.show()

# %%
# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(accuracy_series[0], pool_tot_expenses, label='GPT only')
plt.plot(accuracy_series[1],pool_tot70_expenses, label='GPT confidence > 70')
plt.plot(accuracy_series[2],pool_tot80_expenses, label='GPT confidence > 80')
plt.plot(accuracy_series[3],pool_tot90_expenses, label='GPT confidence > 90')
plt.plot(accuracy_series[4],pool_tot100_expenses, label='Human only')
plt.plot(accuracy_series[5],pool_tot_few_expenses, label='Few-shot < 70')


plt.ylabel('Expenses')
plt.xlabel('F1-Score')
# plt.title('Cost per F1-Score IMDB')
plt.legend()
plt.grid()

# Set y-axis to logarithmic scale
plt.yscale('log')

plt.show()

# %%
avg_lentgh= 766.19 #news
few_lentgh= 407 #news
manual_price= (91.95/50000) * avg_lentgh
llm_price = (0.0015 / 750) * avg_lentgh
few_price = (0.0015 / 750) * (avg_lentgh+few_lentgh)

# %%
print(manual_price)
print(llm_price)
# Out:
# 1.4090234100000003
# 0.00153238

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths
accuracy_file_paths = [


]
count_file_paths = [


]

accuracy_series = []
count_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for count in count_file_paths:
    df = pd.read_excel(count)
    count_series.append(df[0])

# Calculate expenses for each scenario
pool_tot_expenses = [(200 + i * 20) * llm_price for i in range(len(accuracy_series[0]))]
pool_tot100_expenses = [(200 + i * 20) * manual_price for i in range(len(accuracy_series[0]))]
pool_tot70_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[0])
]
pool_tot80_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[1])
]
pool_tot90_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[2])
]
pool_tot_few_expenses= [
    (count * few_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[3])
]

# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(pool_tot_expenses, accuracy_series[0], label='GPT only')
plt.plot(pool_tot70_expenses,[x + 0.001 for x in accuracy_series[1]], label='GPT confidence > 70')
plt.plot(pool_tot80_expenses, accuracy_series[2], label='GPT confidence > 80')
plt.plot(pool_tot90_expenses, accuracy_series[3], label='GPT confidence > 90')
plt.plot(pool_tot100_expenses, accuracy_series[4], label='Human only')
plt.plot(pool_tot_few_expenses, accuracy_series[5], label='Few-shot (<80)')


plt.xlabel('Expenses')
plt.xlabel('F1-Score')
plt.title('Cost per F1-Score Fake News')
plt.legend()
plt.grid()

plt.show()

# %%
# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(accuracy_series[0], pool_tot_expenses, label='GPT only')
plt.plot([x + 0.00 for x in accuracy_series[1]],[y + 0.03 for y in pool_tot70_expenses], label='GPT confidence > 70')
plt.plot(accuracy_series[2],pool_tot80_expenses, label='GPT confidence > 80')
plt.plot(accuracy_series[3],pool_tot90_expenses, label='GPT confidence > 90')
plt.plot(accuracy_series[4],pool_tot100_expenses, label='Human only')
plt.plot(accuracy_series[5],pool_tot_few_expenses, label='Few-shot < 80')

plt.ylabel('Expenses')
plt.xlabel('F1-Score')
# plt.title('Cost per F1-Score Fake News')
plt.legend()
plt.grid()

# Set y-axis to logarithmic scale
plt.yscale('log')

plt.show()

# %%
avg_lentgh= 405.07 #genre
few_lentgh= 313 #genre
manual_price= (91.95/50000) * avg_lentgh
llm_price = (0.0015 / 750) * avg_lentgh
few_price = (0.0015 / 750) * (avg_lentgh+few_lentgh)

# %%
print(manual_price)
print(llm_price)
# Out:
# 0.74492373
# 0.00081014

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the file paths
accuracy_file_paths = [


]
count_file_paths = [

]

accuracy_series = []
count_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for count in count_file_paths:
    df = pd.read_excel(count)
    count_series.append(df[0])

# Calculate expenses for each scenario
pool_tot_expenses = [(200 + i * 20) * llm_price for i in range(len(accuracy_series[0]))]
pool_tot100_expenses = [(200 + i * 20) * manual_price for i in range(len(accuracy_series[0]))]
pool_tot70_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[0])
]
pool_tot80_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[1])
]
pool_tot90_expenses = [
    (count * manual_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[2])
]
pool_tot_few_expenses= [
    (count * few_price) + ((200 + i * 20 - count) * llm_price) for i, count in enumerate(count_series[3])
]

# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(pool_tot_expenses, accuracy_series[0], label='GPT only')
plt.plot(pool_tot70_expenses, accuracy_series[1], label='GPT confidence > 70')
plt.plot(pool_tot80_expenses, accuracy_series[2], label='GPT confidence > 80')
plt.plot(pool_tot90_expenses, accuracy_series[3], label='GPT confidence > 90')
plt.plot(pool_tot100_expenses, accuracy_series[4], label='Human only')
plt.plot(pool_tot_few_expenses, accuracy_series[5], label='Few-shot (<80)')


plt.xlabel('Expenses')
plt.xlabel('F1-Score')
plt.title('Cost per F1-Score Movies Genre')
plt.legend()
plt.grid()

plt.show()

# %%
# Create a plot
plt.figure(figsize=(10, 6))

plt.plot(accuracy_series[0], pool_tot_expenses, label='GPT only')
plt.plot(accuracy_series[1],pool_tot70_expenses, label='GPT confidence > 70')
plt.plot(accuracy_series[2],pool_tot80_expenses, label='GPT confidence > 80')
plt.plot(accuracy_series[3],pool_tot90_expenses, label='GPT confidence > 90')
plt.plot(accuracy_series[4],pool_tot100_expenses, label='Human only')
plt.plot( accuracy_series[5],pool_tot_few_expenses, label='Few-shot < 80')


plt.ylabel('Expenses')
plt.xlabel('F1-Score')
# plt.title('Cost per F1-Score Movies Genre')
plt.legend()
plt.grid()

# Set y-axis to logarithmic scale
plt.yscale('log')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# File paths for accuracy
accuracy_file_paths = [


]

# File paths for different portion
portion_file_paths = [


]

# Create empty lists to store accuracy and portion series
accuracy_series = []
portion_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for file_path in portion_file_paths:
    df = pd.read_excel(file_path)
    portion_series.append(df[0])

# Compute the tick locations and labels for the x-axis
# tick_locations = list(range(0, 251, 5))  # start from 0 because 2% corresponds to 0th iteration
# tick_labels = list(range(2, 53))  # 2 to 52

tick_locations = [0, 15, 40, 65, 90, 115, 140, 165, 190, 215, 240, 250]
tick_labels = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 52]

plt.figure(figsize=(15, 9))

# Plot accuracy and portion series with matching colors (lines only, no markers)
for i in range(len(accuracy_series)):
    plt.plot(accuracy_series[i], linestyle='-', linewidth=1)
    plt.plot(portion_series[i], linestyle='--', linewidth=1, color=plt.gca().lines[-1].get_color())

plt.xlabel('Percentage of Training data')
plt.ylabel('F1-Score')
plt.xticks(tick_locations, tick_labels)  # Set the tick marks and labels for the x-axis
plt.legend(['GPT Only', 'GPT Only(random)','GPT confidence > 70', 'GPT confidence > 70(random)',  'GPT confidence > 80', 'GPT confidence > 80(random)','GPT confidence > 90', 'GPT confidence > 90(random)', 'Human Only' , 'Human Only(random)','Few_Shot < 80','Few_Shot < 80(random)'], loc='lower right')
# plt.title('Accuracy and Portion Comparison Movies Genre')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File paths for accuracy
accuracy_file_paths = [


]

# File paths for different portion
portion_file_paths = [


]


# Create empty lists to store accuracy and portion series
accuracy_series = []
portion_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for file_path in portion_file_paths:
    df = pd.read_excel(file_path)
    portion_series.append(df[0])

# Compute the tick locations and labels for the x-axis
# tick_locations = list(range(0, 251, 5))  # start from 0 because 2% corresponds to 0th iteration
# tick_labels = list(range(2, 53))  # 2 to 52

tick_locations = [0, 15, 40, 65, 90, 115, 140, 165, 190, 215, 240, 250]
tick_labels = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 52]

plt.figure(figsize=(10, 6))

# Plot accuracy and portion series with matching colors (lines only, no markers)
for i in range(len(accuracy_series)):
    if i==1:
          plt.plot([x + 0.005 for x in accuracy_series[i]], linestyle='-', linewidth=1)
          plt.plot([x + 0.005 for x in portion_series[i]], linestyle='--', linewidth=1, color=plt.gca().lines[-1].get_color())

    else:
          plt.plot(accuracy_series[i], linestyle='-', linewidth=1)
          plt.plot(portion_series[i], linestyle='--', linewidth=1, color=plt.gca().lines[-1].get_color())

plt.xlabel('Percentage of Training data')
plt.ylabel('F1-Score')
plt.xticks(tick_locations, tick_labels)  # Set the tick marks and labels for the x-axis
plt.legend(['GPT Only', 'GPT Only(random)','GPT confidence > 70', 'GPT confidence > 70(random)',  'GPT confidence > 80', 'GPT confidence > 80(random)','GPT confidence > 90', 'GPT confidence > 90(random)', 'Human Only' , 'Human Only(random)','Few_Shot < 80','Few_Shot < 80(random)'])
# plt.title('Accuracy and Portion Comparison fake news')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File paths for accuracy
accuracy_file_paths = [


]

# File paths for different portion
portion_file_paths = [


]

# Create empty lists to store accuracy and portion series
accuracy_series = []
portion_series = []

# Read accuracy from each file and append to accuracy series list
for file_path in accuracy_file_paths:
    df = pd.read_excel(file_path)
    accuracy_series.append(df[0])

# Read portion from each file and append to portion series list
for file_path in portion_file_paths:
    df = pd.read_excel(file_path)
    portion_series.append(df[0])

# Compute the tick locations and labels for the x-axis
# tick_locations = list(range(0, 251, 5))  # start from 0 because 2% corresponds to 0th iteration
# tick_labels = list(range(2, 53))  # 2 to 52

tick_locations = [0, 15, 40, 65, 90, 115, 140, 165, 190, 215, 240, 250]
tick_labels = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 52]

plt.figure(figsize=(10, 6))

# Plot accuracy and portion series with matching colors (lines only, no markers)
offset=0.005
for i in range(len(accuracy_series)):
    plt.plot([x + i * offset for x in accuracy_series[i]], linestyle='-', linewidth=1)
    plt.plot([y + i * offset for y in portion_series[i]], linestyle='--', linewidth=1, color=plt.gca().lines[-1].get_color())

plt.xlabel('Percentage of Training data')
plt.ylabel('F1-Score')
plt.xticks(tick_locations, tick_labels)  # Set the tick marks and labels for the x-axis
plt.legend(['GPT Only', 'GPT Only(random)','GPT confidence > 70', 'GPT confidence > 70(random)',  'GPT confidence > 80', 'GPT confidence > 80(random)','GPT confidence > 90', 'GPT confidence > 90(random)', 'Human Only' , 'Human Only(random)','Few_Shot < 70','Few_Shot < 70(random)'])
# plt.title('Accuracy and Portion Comparison IMDB')

plt.show()
